# %% [markdown]
# pydantic basics

# %%
from pydantic import BaseModel
from typing import Optional

# %%
class Person(BaseModel):
    name: str
    age: int
    city: str
    salary: Optional[float] = None

# %%
person = Person(name="Alice", age=30, city="New York")
print(person)
# Out:
# name='Alice' age=30 city='New York' salary=None

# %%
type(person)
# Out:
# __main__.Person
